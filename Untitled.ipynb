# %%
using Plots

# %%
plot()

# %%
plot(rand(10))

# %%
plot(rand(10),rand(10))

# %%
plot(rand(10,3))

# %%
plot(sin,rand(10))

# %%
plot(sin,0:0.1:π)

# %%
plot(sin,0:0.1:2π)

# %%
plot(cos,0:0.1:2π)

# %%
plot([sin,cos],0:0.1:2π, labels = ["sin" "cos"], xlabel = "x", ylabel = "y", title = "sin and cos")

# %%
#plot(x,y)
#plot(function,x)
